# %% [markdown]
# ### Analyzing and Visualizating

# %% [markdown]
# Let's look if there any dependencies between retweets count and favorites count (it's clearly should be, but I plan to ensure myself by looking at the plot below).

# %% [markdown]
# ![image.png](attachment:35afaf67-1d8e-4f0f-bf9d-4130f919e63c.png)

# %% [markdown]
# The plot above clearly displays those dependencies. Also, let's look at the distribution of ratings.

# %% [markdown]
# ![image.png](attachment:d6fa5959-041c-4e49-a5f2-daac4b089d59.png)

# %% [markdown]
# Also, I want to look is there any dependencies of ratings and likes. Plot down there have some biases based on my decisions in data cleaning stage, so ratings 17 and 18 could be ignored (i imputed those ratings manually in case that in original message rating's was above 100)

# %% [markdown]
# ![image.png](attachment:99d3c2f0-d510-45e3-b384-58bd57920085.png)

# %% [markdown]
# ![image.png](attachment:78c312ea-5a5f-4885-bda0-b96a235a8a5a.png)

# %% [markdown]
# We have clear evidence that the more rating dogs receive - the more likes and retweets he will have he will have.

# %% [markdown]
# While working with those data I found a really interesting explanation of dog stages. So there 4 types of them: upper, puppo, floofer, and doggo. Question is - which stage has the highest average rating? Answer: doggo + puppo. Little explanation, this stage we receive if we have 2 types of dogs in the picture. And on average, people give these pictures high marks and a lot of likes. Pictures below.

# %% [markdown]
# ![image.png](attachment:41853b63-85f6-4562-9bb9-afcee569e434.png)

# %% [markdown]
# ![image.png](attachment:b6fa820d-94b8-4a50-a883-406eabfe6a5f.png)

# %% [markdown]
# ![image.png](attachment:fcbba2cb-85e7-4e26-9304-7ae876b3fcdc.png)

# %% [markdown]
# Let's speek about breed representation in analyzing data. What breed have most like's, ratings, finally, what is most common breed? Disclaimer: while we try to find what breed have dog on picture we use some machine learning techniques, and breed has been identified with some probability. For the formation of graphs, I have chosen a 70% threshold, i.e. if the breed is determined with 70% accuracy, I believe that it is a dog of this particular breed.
# For me, before making that analysis I thought that most ratings will have a golden retriever, but let's look at plots down there.

# %% [markdown]
# ![image.png](attachment:752a6c00-7bab-4a1b-9fa8-4d4eb32d3d0c.png)

# %% [markdown]
# ![image.png](attachment:866ef856-885c-48ed-9c95-2ce644c106bc.png)

# %% [markdown]
# ![image.png](attachment:8faf109c-d55b-47b9-8ea1-21331afa69eb.png)

# %% [markdown]
# ![image.png](attachment:efb04954-405e-459d-8ad8-d5b92214d1aa.png)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# That was an interesting assessment, that help's me muster skills in data wrangling and also helps me find some interesting information about dog stages and about data provided, like:
#
# - Dependencies of retweets and favorites: proven
# - Dependencies of ratings likes and retweets: prove
# - What stage of dog do people prefer: dog + puppy :)
# - And finally what most common and what most liked breed in our data: most common: golden retriever, most liked: black-and-tan coonhound
